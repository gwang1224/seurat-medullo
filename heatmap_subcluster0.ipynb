# %%
import csv

file_path = '/Users/gracewang/Documents/mesirov_lab/seurat-medullo/panglao_subclusters/subcluster0.csv'  # Replace with the path to your TSV file

# Open the TSV file and read its content into a list of dictionaries
with open(file_path, 'r') as tsv_file:
    # Use csv.reader with the tab delimiter
    tsv_reader = csv.reader(tsv_file, delimiter='\t')

    # Convert the TSV content to a list of lists
    tsv_data = list(tsv_reader)

gene_list = []
cell_type = []
for i in tsv_data:
    # print(i)
    gene_list.append(i[1])
    cell_type.append(i[5])

gene_list = list(set(gene_list))
cell_type = list(set(cell_type))
print(gene_list)
print(cell_type)
# Out:
# ['JUN', 'TXNIP', 'CXCR3', 'HSPA1A', 'DNAJC15', 'FGF13', 'ITGB1', 'CRIP1', 'CCL5', 'S100A10', 'KLF2', 'HSPA1B', 'UBA52']
# ...

# %%
genes = ['JUN', 'TXNIP', 'CXCR3', 'HSPA1A', 'DNAJC15', 'FGF13', 'ITGB1', 'CRIP1', 'CCL5', 'S100A10', 'KLF2', 'HSPA1B', 'UBA52']

# Create a dictionary with genes as keys and initialize values to 0
gene_dict = {gene: 0 for gene in genes}

# Print the resulting dictionary
print(gene_dict)
# Out:
# {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 0, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}

# %%
cell_types = ['T memory cells', 'Tanycytes', 'Granulosa cells', 'Ependymal cells', 'Alveolar macrophages', 'Fibroblasts', 'Decidual cells', 'Sertoli cells', 'Microglia', 'Basophils', 'Pancreatic stellate cells', 'Loop of Henle cells', 'Dendritic cells', 'Osteoclasts', 'Chondrocytes', 'Proximal tubule cells', 'Melanocytes', 'Smooth muscle cells', 'B cells naive', 'Langerhans cells', 'Leydig cells', 'Erythroid-like and erythroid precursor cells', 'Endothelial cells', 'Basal cells', 'Tuft cells', 'Monocytes', 'Hepatic stellate cells', 'Enteric glia cells', 'Luteal cells', 'Neural stem/precursor cells', 'Trigeminal neurons', 'Gamma delta T cells', 'Airway goblet cells', 'Acinar cells', 'Beta cells', 'Ductal cells', 'Gamma (PP) cells', 'NK cells', 'Interneurons', 'Serotonergic neurons', 'Urothelial cells', 'Endothelial cells (aorta)', 'Cardiomyocytes', 'Keratinocytes', 'Mast cells', 'Enteric neurons', 'Meningeal cells', 'Anterior pituitary gland cells', 'Schwann cells', 'Myocytes', 'Follicular cells', 'Hematopoietic stem cells', 'Stromal cells', 'Mller cells', 'Pulmonary alveolar type II cells', 'Mammary epithelial cells', 'Pericytes', 'Paneth cells', 'Foveolar cells', 'Eosinophils', 'Retinal ganglion cells', 'Epithelial cells', 'Cajal-Retzius cells', 'Salivary mucous cells', 'Principal cells', 'Red pulp macrophages', 'Hepatocytes', 'Neurons', 'Distal tubule cells', 'Podocytes', 'protein-coding gene', 'Spermatocytes', 'Enteroendocrine cells', 'Noradrenergic neurons', 'Ciliated cells', 'Enterocytes', 'Peritubular myoid cells', 'T cells', 'B cells', 'Kupffer cells', 'T regulatory cells', 'Intercalated cells', 'Luminal epithelial cells', 'Astrocytes', 'Parathyroid chief cells', 'Pulmonary alveolar type I cells', 'Nuocytes', 'Plasmacytoid dendritic cells', 'Neuroendocrine cells', 'Oligodendrocyte progenitor cells', 'Neutrophils', 'Platelets', 'Myofibroblasts', 'Adipocytes', 'Unknown', 'Osteoblasts', 'Alpha cells', 'Juxtaglomerular cells', 'Satellite cells', 'Oligodendrocytes', 'Germ cells', 'Clara cells', 'Macrophages', 'Delta cells', 'Myoepithelial cells', 'Choroid plexus cells', 'Myoblasts', 'Vascular smooth muscle cells', 'Retinal progenitor cells', 'Olfactory epithelial cells', 'Cholangiocytes', 'Plasma cells', 'Goblet cells', 'Mesothelial cells', 'Photoreceptor cells']

dict_of_dicts = {}

for cell in cell_types:
    dict_of_dicts[cell] = gene_dict

print(dict_of_dicts)
# Out:
# {'T memory cells': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 0, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Tanycytes': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 0, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Granulosa cells': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 0, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Ependymal cells': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 0, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Alveolar macrophages': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 0, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Fibroblasts': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CR
# ...

# %%
genes = ['JUN', 'TXNIP', 'CXCR3', 'HSPA1A', 'DNAJC15', 'FGF13', 'ITGB1', 'CRIP1', 'CCL5', 'S100A10', 'KLF2', 'HSPA1B', 'UBA52']
gene_dict = {gene: 0 for gene in genes}

cell_types = ['T memory cells', 'Tanycytes', 'Granulosa cells', 'Ependymal cells', 'Alveolar macrophages', 'Fibroblasts', 'Decidual cells', 'Sertoli cells', 'Microglia', 'Basophils', 'Pancreatic stellate cells', 'Loop of Henle cells', 'Dendritic cells', 'Osteoclasts', 'Chondrocytes', 'Proximal tubule cells', 'Melanocytes', 'Smooth muscle cells', 'B cells naive', 'Langerhans cells', 'Leydig cells', 'Erythroid-like and erythroid precursor cells', 'Endothelial cells', 'Basal cells', 'Tuft cells', 'Monocytes', 'Hepatic stellate cells', 'Enteric glia cells', 'Luteal cells', 'Neural stem/precursor cells', 'Trigeminal neurons', 'Gamma delta T cells', 'Airway goblet cells', 'Acinar cells', 'Beta cells', 'Ductal cells', 'Gamma (PP) cells', 'NK cells', 'Interneurons', 'Serotonergic neurons', 'Urothelial cells', 'Endothelial cells (aorta)', 'Cardiomyocytes', 'Keratinocytes', 'Mast cells', 'Enteric neurons', 'Meningeal cells', 'Anterior pituitary gland cells', 'Schwann cells', 'Myocytes', 'Follicular cells', 'Hematopoietic stem cells', 'Stromal cells', 'Mller cells', 'Pulmonary alveolar type II cells', 'Mammary epithelial cells', 'Pericytes', 'Paneth cells', 'Foveolar cells', 'Eosinophils', 'Retinal ganglion cells', 'Epithelial cells', 'Cajal-Retzius cells', 'Salivary mucous cells', 'Principal cells', 'Red pulp macrophages', 'Hepatocytes', 'Neurons', 'Distal tubule cells', 'Podocytes', 'protein-coding gene', 'Spermatocytes', 'Enteroendocrine cells', 'Noradrenergic neurons', 'Ciliated cells', 'Enterocytes', 'Peritubular myoid cells', 'T cells', 'B cells', 'Kupffer cells', 'T regulatory cells', 'Intercalated cells', 'Luminal epithelial cells', 'Astrocytes', 'Parathyroid chief cells', 'Pulmonary alveolar type I cells', 'Nuocytes', 'Plasmacytoid dendritic cells', 'Neuroendocrine cells', 'Oligodendrocyte progenitor cells', 'Neutrophils', 'Platelets', 'Myofibroblasts', 'Adipocytes', 'Unknown', 'Osteoblasts', 'Alpha cells', 'Juxtaglomerular cells', 'Satellite cells', 'Oligodendrocytes', 'Germ cells', 'Clara cells', 'Macrophages', 'Delta cells', 'Myoepithelial cells', 'Choroid plexus cells', 'Myoblasts', 'Vascular smooth muscle cells', 'Retinal progenitor cells', 'Olfactory epithelial cells', 'Cholangiocytes', 'Plasma cells', 'Goblet cells', 'Mesothelial cells', 'Photoreceptor cells']

dict_of_dicts = {}

for cell in cell_types:
    # Create a copy of gene_dict for each cell type
    dict_of_dicts[cell] = gene_dict.copy()

# Print the resulting dictionary
print(dict_of_dicts)
# Out:
# {'T memory cells': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 0, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Tanycytes': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 0, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Granulosa cells': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 0, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Ependymal cells': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 0, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Alveolar macrophages': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 0, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Fibroblasts': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CR
# ...

# %%
for sample in tsv_data:
    if len(sample) == 7:
        if int(sample[6]) < 20:
            # print(sample)
            gene = sample[1]
            cell = sample[5]
            dict_of_dicts[cell][gene] += 1


print(dict_of_dicts)
# Out:
# {'T memory cells': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 1, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 5, 'CCL5': 14, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Tanycytes': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 0, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Granulosa cells': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 0, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Ependymal cells': {'JUN': 5, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 2, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Alveolar macrophages': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 6, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Fibroblasts': {'JUN': 51, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 21, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 
# ...

# %%
# Create a copy of keys
samples_to_delete = list(dict_of_dicts.keys())

# Iterate over the copy
for sample in samples_to_delete:
    all_zero = all(value == 0 for value in dict_of_dicts[sample].values())
    if all_zero:
        del dict_of_dicts[sample]

# Print the updated dictionary
print("Updated dictionary:", dict_of_dicts)
print(len(dict_of_dicts))
# Out:
# Updated dictionary: {'T memory cells': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 1, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 5, 'CCL5': 14, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Ependymal cells': {'JUN': 5, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 2, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Alveolar macrophages': {'JUN': 0, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 6, 'CCL5': 0, 'S100A10': 0, 'KLF2': 0, 'HSPA1B': 0, 'UBA52': 0}, 'Fibroblasts': {'JUN': 51, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 21, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 17, 'CCL5': 0, 'S100A10': 1, 'KLF2': 0, 'HSPA1B': 1, 'UBA52': 0}, 'Microglia': {'JUN': 40, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 3, 'DNAJC15': 0, 'FGF13': 0, 'ITGB1': 0, 'CRIP1': 0, 'CCL5': 1, 'S100A10': 0, 'KLF2': 1, 'HSPA1B': 0, 'UBA52': 0}, 'Basophils': {'JUN': 4, 'TXNIP': 0, 'CXCR3': 0, 'HSPA1A': 0, 'DNAJC15': 0, 'FGF13':
# ...

# %%
import pandas as pd
dataframe = pd.DataFrame(dict_of_dicts)

dataframe = dataframe.transpose()
print(dataframe)

dataframe.to_csv('test.csv', index=True)
# Out:
#                               JUN  TXNIP  CXCR3  HSPA1A  DNAJC15  FGF13  \
# T memory cells                  0      0      0       1        0      0
# Ependymal cells                 5      0      0       0        0      0
# Alveolar macrophages            0      0      0       0        0      0
# Fibroblasts                    51      0      0      21        0      0
# Microglia                      40      0      0       3        0      0
# ...                           ...    ...    ...     ...      ...    ...
# Vascular smooth muscle cells    1      0      0       0        0      0
# Cholangiocytes                  3      0      0       2        0      0
# Plasma cells                   12      0      0       1        0      0
# Goblet cells                    0      0      0       0        0      0
# Mesothelial cells               0      0      0       0        0      0
#
#                               ITGB1  CRIP1  CCL5  S100A10  KLF2  HSPA1B  UBA52
# ...
